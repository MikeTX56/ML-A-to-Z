# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.preprocessing import StandardScaler
from scipy import stats
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data_train = pd.read_csv("../data/train.csv")

# %% [markdown]
# In oredr to understand our data, we can look each variable and try to understand their meaning and relevance to this problem
# we can classify this data into segment, that are the identification of variables' segments
# we can devide them into 3
# 1. building, a variable that relates to the physical characterstics of the building
# 2. space, a variable that reports space properties of the house
# 3. location, a variable that gives the info about the palce where the house is located.
#
# Expectation,  variable influence in "SalesPrice"

# %% [markdown]
# ##### analaysing "SalePrice"

# %%
data_train["SalePrice"].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
sns.distplot(data_train["SalePrice"])
# Out:
# <Axes: xlabel='SalePrice', ylabel='Density'>

# %% [markdown]
# #### Relationship with numerical variable

# %% [markdown]
# the following variables can play an important role in this problem:
#
#     OverallQual (which is a variable that I don't like because I don't know how it was     computed; a funny exercise would be to predict 'OverallQual' using all the other variables available).
#     YearBuilt.
#     TotalBsmtSF.
#     GrLivArea.
#
#     OverQuall and yearbuilt are the 'Bulilding' variables
#     TotalBsmtSF and GrLivArea are the location variables

# %%
data = pd.concat([data_train["SalePrice"], data_train['GrLivArea']], axis = 1)
data.plot.scatter(x = 'GrLivArea', y = "SalePrice",ylim = (0.80000) )
# Out:
# <Axes: xlabel='GrLivArea', ylabel='SalePrice'>

# %%
data = pd.concat([data_train["SalePrice"], data_train['TotalBsmtSF']], axis = 1)
data.plot.scatter(x = 'TotalBsmtSF', y = 'SalePrice')
# Out:
# <Axes: xlabel='TotalBsmtSF', ylabel='SalePrice'>

# %% [markdown]
# ##### Relation with catagorical features
